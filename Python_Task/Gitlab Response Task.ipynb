# %%
from requests import Session
import json
import requests

# %%
import requests

# Assuming 's' is your requests.Session() object with login_data already set

# URL of the GitLab repository
repo_url = "https://gitlab.com/api/v4/projects/gitlab-org%2Fgitlab-docs/repository/tree"

# Headers with the personal access token
headers = {
    "PRIVATE-TOKEN": "glpat-YsEACexDjhJWdAFLExNB"
}

# Make a GET request to fetch the list of files
response = s.get(repo_url, headers=headers)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON response to get the list of files
    files = response.json()
    
    # Display the list of files
    for file in files:
        print(file['name'])
else:
    # Display an error message if the request was not successful
    print(f"Error: {response.status_code} - {response.text}")
data = response.json()
print(data)
# Out:
# .gitlab
# bin
# config
# content
# doc
# dockerfiles
# layouts
# lib
# scripts
# spec
# tasks
# .devfile.yaml
# .dockerignore
# .editorconfig
# .eslintignore
# .eslintrc.yml
# .gitattributes
# .gitignore
# .gitlab-ci.yml
# .gitpod.Dockerfile
# ...

# %%
import requests
import json
from datetime import datetime
 
# personal access token generated from peronal account
private_token = 'glpat-8KFNcmr2yViNfQYhNa6j'

project_path = 'gitlab-org%2Fgitlab-docs'
project_id = '1794617' 
 
# API endpoint 
project_details_url = f'https://gitlab.com/api/v4/projects/{project_id}'
contributors_api_url = f'https://gitlab.com/api/v4/projects/{project_id}/repository/contributors'
tree_api_url = f'https://gitlab.com/api/v4/projects/{project_path}/repository/tree'

 
# Parameters for the API requests
params = {'private_token': private_token, 'id': project_id,'recursive': True,'per_page': 100}

def get_files_from_all_pages(url):
    all_files = []
    page = 1
    while True:
        response = requests.get(url.format(project_id=project_id), params={**params, 'page': page})
        if response.status_code == 200:
            data = response.json()
            all_files.extend(data)
            if len(data) < 100:  # Assuming 100 items per page, adjust as needed
                break
            page += 1
        else:
            print('Failed to retrieve data:', response.status_code, response.text)
            return None
    return all_files
 
# Get files data
files_data = get_files_from_all_pages(base_url)
 
if files_data is not None:
    try:
        contributors_data = requests.get(contributors_url.format(project_id=project_id), params=params)
        project_data = requests.get(project_details_url.format(project_id=project_id), params=params)
 
        if contributors_data.status_code == 200 and project_data.status_code == 200:
            contributors_info = [{"name": contributor["name"], "email": contributor["email"]} for contributor in contributors_data.json()]
            project_name = project_data.json()["name"]
 
            output = {
                "id": project_id,
                "name": project_name,
                "contributors": contributors_info,
                "contents": {
                    "meta": {
                        "folders_count": 0,
                        "files_count": 0
                    },
                    "folders": [],
                    "files": []
                }
            }
 
            for item in files_data:
                if item['type'] == 'tree':
                    output["contents"]["meta"]["folders_count"] += 1
                    output["contents"]["folders"].append({
                        "folder_name": item["name"],
                        "folder_path": item["path"],
                        "folder_mode": item["mode"]
                    })
                elif item['type'] == 'blob':
                    output["contents"]["meta"]["files_count"] += 1
                    output["contents"]["files"].append({
                        "file_name": item["name"],
                        "file_path": item["path"],
                        "file_mode": item["mode"]
                    })
 
            timestamp = datetime.now().strftime("%Y%m%d%H%M%S")
            file_name = f"repo-query-{timestamp}.json"
            print(json.dumps(output, indent=4))
            with open(file_name, 'w') as file:
                json.dump(output, file, indent=4)
        else:
            print('Failed to retrieve contributors or project data')
 
    except json.JSONDecodeError as e:
        print('Error decoding JSON response:', e)
# Out:
# {
#     "id": "1794617",
#     "name": "GitLab Docs",
#     "contributors": [
#         {
#             "name": "Mariia Solodovnik",
#             "email": "msolodovnik-ext@gitlab.com"
#         },
#         {
#             "name": "Edward Angert",
#             "email": "19517898-eangert-ext@users.noreply.gitlab.com"
#         },
#         {
#             "name": "Michael Friedrich",
#             "email": "mfriedrich@gitlab.com"
#         },
#         {
#             "name": "Martin \u010cavoj",
#             "email": "mcavoj@gitlab.com"
#         },
#         {
#             "name": "Ian Baum",
#             "email": "ibaum@gitlab.com"
#         },
#         {
#             "name": "Arpit Gogia",
#             "email": "12347103-arpitgogia@users.noreply.gitlab.com"
#         },
#         {
#             "name": "Imre Farkas",
#             "email": "ifarkas@gitlab.com"
#         },
#         {
#             "name": "Vladimir Shushlin",
# ...

# %%
import os
os.listdir()
# Out:
# Out[18]: ['preload_class.lst',
#  'azure',
#  'conf',
#  'hadoop_accessed_config.lst',
#  'repo-query-20240212115133.json',
#  'repo-query-20240212112043.json',
#  'repo-query-20240212112407.json',
#  'ganglia',
#  'metastore_db',
#  'repo-query-20240212112114.json',
#  'logs',
#  'eventlogs',
#  'repo-query-20240212111910.json']

# %%
with open("repo-query-20240212115133.json","r") as f:
    print(f.read())
# Out:
# {
#     "id": "1794617",
#     "name": "GitLab Docs",
#     "contributors": [
#         {
#             "name": "Mariia Solodovnik",
#             "email": "msolodovnik-ext@gitlab.com"
#         },
#         {
#             "name": "Edward Angert",
#             "email": "19517898-eangert-ext@users.noreply.gitlab.com"
#         },
#         {
#             "name": "Michael Friedrich",
#             "email": "mfriedrich@gitlab.com"
#         },
#         {
#             "name": "Martin \u010cavoj",
#             "email": "mcavoj@gitlab.com"
#         },
#         {
#             "name": "Ian Baum",
#             "email": "ibaum@gitlab.com"
#         },
#         {
#             "name": "Arpit Gogia",
#             "email": "12347103-arpitgogia@users.noreply.gitlab.com"
#         },
#         {
#             "name": "Imre Farkas",
#             "email": "ifarkas@gitlab.com"
#         },
#         {
#             "name": "Vladimir Shushlin",
# ...
