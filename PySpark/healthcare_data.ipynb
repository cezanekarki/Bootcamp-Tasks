# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %%
# %fs ls dbfs:///FileStore/tables/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/Address-1.xlsx</td><td>Address-1.xlsx</td><td>151315</td><td>1706174779000</td></tr><tr><td>dbfs:/FileStore/tables/Address-2.xlsx</td><td>Address-2.xlsx</td><td>151315</td><td>1706405632000</td></tr><tr><td>dbfs:/FileStore/tables/Address.xlsx</td><td>Address.xlsx</td><td>151315</td><td>1706079714000</td></tr><tr><td>dbfs:/FileStore/tables/Detail.csv</td><td>Detail.csv</td><td>208476</td><td>1706073638000</td></tr><tr><td>dbfs:/FileStore/tables/Drugs_package.csv</td><td>Drugs_package.csv</td><td>27234691</td><td>1707889086000</td></tr><tr><td>dbfs:/FileStore/tables/Drugs_product.csv</td><td>Drugs_product.csv</td><td>38743242</td><td>1707889090000</td></tr><tr><td>dbfs:/FileStore/tables/Eligibility_Mock_Data___US_Healthcare_Bootcamp-1.xlsx</td><td>Eligibility_Mock_Data___US_Healthcare_Bootcamp-1.xlsx</td><td>39904</td><td>1708942729000</td></tr><tr><td>dbfs:/FileStore/tables/Eligibility_Mock_Data___US_Healthcare_Bootcamp.xlsx</td><td>Eligibility_Mock_Data___US_Healthcare_Bootcamp.xlsx</td><td>35701</td><td>1708506442000</td></tr><tr><td>dbfs:/FileStore/tables/Project_1.xlsx</td><td>Project_1.xlsx</td><td>422501</td><td>1706519350000</td></tr><tr><td>dbfs:/FileStore/tables/contactinfo.txt</td><td>contactinfo.txt</td><td>49969</td><td>1706075806000</td></tr><tr><td>dbfs:/FileStore/tables/csv/</td><td>csv/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/final/</td><td>final/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/header-1.json</td><td>header-1.json</td><td>115560</td><td>1706076109000</td></tr><tr><td>dbfs:/FileStore/tables/header-2.json</td><td>header-2.json</td><td>186</td><td>1706076841000</td></tr><tr><td>dbfs:/FileStore/tables/header-3.json</td><td>header-3.json</td><td>186</td><td>1706077060000</td></tr><tr><td>dbfs:/FileStore/tables/header-4.json</td><td>header-4.json</td><td>186</td><td>1706174821000</td></tr><tr><td>dbfs:/FileStore/tables/header-5.json</td><td>header-5.json</td><td>115560</td><td>1706175003000</td></tr><tr><td>dbfs:/FileStore/tables/header.json</td><td>header.json</td><td>115560</td><td>1706075692000</td></tr><tr><td>dbfs:/FileStore/tables/hello.json</td><td>hello.json</td><td>186</td><td>1706077165000</td></tr><tr><td>dbfs:/FileStore/tables/json/</td><td>json/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/parquet/</td><td>parquet/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
from pyspark.sql import SparkSession, functions as F
 
spark=SparkSession.builder.getOrCreate()

path = '/FileStore/tables/Eligibility_Mock_Data___US_Healthcare_Bootcamp-1.xlsx'
dataFormat = "com.crealytics.spark.excel"
 
enrollment_sheet_name="Enrollment Mock Data"
demographics_sheet_name="Demographics Mock Data"
gender_crosswalk = "Gender Crosswalk"
group_crosswalk = "Group Crosswalk"
relationship_crosswalk = "Relationship Crosswalk"
coverage_crosswalk = "Coverage Crosswalk"
plan_crosswalk = "Plan Crosswalk"

enrollment_df = spark.read.format(dataFormat).option("inferschema", True).option("header", True).option("dataAddress", f"'{enrollment_sheet_name}'!").load(path)
demographics_df = spark.read.format(dataFormat).option("inferschema", True).option("header", True).option("dataAddress", f"'{demographics_sheet_name}'!").load(path)
gender_df = spark.read.format(dataFormat).option("inferschema", True).option("header", True).option("dataAddress", f"'{gender_crosswalk}'!").load(path)
group_df = spark.read.format(dataFormat).option("inferschema", True).option("header", True).option("dataAddress", f"'{group_crosswalk}'!").load(path)
relationship_df = spark.read.format(dataFormat).option("inferschema", True).option("header", True).option("dataAddress", f"'{relationship_crosswalk}'!").load(path)
coverage_df = spark.read.format(dataFormat).option("inferschema", True).option("header", True).option("dataAddress", f"'{coverage_crosswalk}'!").load(path)
coverage_df = spark.read.format(dataFormat).option("inferschema", True).option("header", True).option("dataAddress", f"'{coverage_crosswalk}'!").load(path)
plan_df = spark.read.format(dataFormat).option("inferschema", True).option("header", True).option("dataAddress", f"'{plan_crosswalk}'!").load(path)

# %%
enrollment_df.printSchema()
# Out:
# root
#  |-- MEMBER_ID: string (nullable = true)
#  |-- MEMBER_STATUS: string (nullable = true)
#  |-- GROUP_ID: string (nullable = true)
#  |-- COVERAGE_TYPE: string (nullable = true)
#  |-- PLAN_ID: double (nullable = true)
#  |-- VENDOR: string (nullable = true)
#  |-- EFFECTIVE_DATE: timestamp (nullable = true)
#  |-- TERMINATION_DATE: string (nullable = true)

# %%
new_column_names = ["member_id",
"member_status",
"group_id",
"coverage_type",
"plan_id",
"vendor",
"effective_date",
"termination_date"]
enrollment_df = enrollment_df.toDF(*new_column_names)

# %%
enrollment_df.printSchema()
# Out:
# root
#  |-- member_id: string (nullable = true)
#  |-- member_status: string (nullable = true)
#  |-- group_id: string (nullable = true)
#  |-- coverage_type: string (nullable = true)
#  |-- plan_id: double (nullable = true)
#  |-- vendor: string (nullable = true)
#  |-- effective_date: timestamp (nullable = true)
#  |-- termination_date: string (nullable = true)

# %%
demographics_df.printSchema()
# Out:
# root
#  |-- MEMBER_ID: string (nullable = true)
#  |-- EMPLOYEE_ID: string (nullable = true)
#  |-- FIRST_NAME: string (nullable = true)
#  |-- LAST_NAME: string (nullable = true)
#  |-- MIDDLE_NAME: string (nullable = true)
#  |-- GENDER: double (nullable = true)
#  |-- DOB: string (nullable = true)
#  |-- RELATIONSHIP: string (nullable = true)
#  |-- PERSON_CODE: string (nullable = true)
#  |-- RACE: string (nullable = true)
#  |-- ETHNICITY: string (nullable = true)
#  |-- ADDRESS_1: string (nullable = true)
#  |-- ADDRESS_2: string (nullable = true)
#  |-- CITY: string (nullable = true)
#  |-- STATE: string (nullable = true)
#  |-- COUNTY: string (nullable = true)
#  |-- ZIP: string (nullable = true)

# %%
new_column_names = ["member_id",
"employee_id",
"first_name",
"last_name",
"middle_name",
"gender",
"dob",
"relationship",
"person_code",
"race",
"ethnicity",
"address_1",
"address_2",
"city",
"state",
"county",
"zip"]
demographics_df = demographics_df.toDF(*new_column_names)

# %%
demographics_df.printSchema()
# Out:
# root
#  |-- member_id: string (nullable = true)
#  |-- employee_id: string (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- last_name: string (nullable = true)
#  |-- middle_name: string (nullable = true)
#  |-- gender: double (nullable = true)
#  |-- dob: string (nullable = true)
#  |-- relationship: string (nullable = true)
#  |-- person_code: string (nullable = true)
#  |-- race: string (nullable = true)
#  |-- ethnicity: string (nullable = true)
#  |-- address_1: string (nullable = true)
#  |-- address_2: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- county: string (nullable = true)
#  |-- zip: string (nullable = true)

# %%
gender_df.printSchema()
# Out:
# root
#  |-- Code: double (nullable = true)
#  |-- Rollup_Code: string (nullable = true)
#  |-- Rollup_Description: string (nullable = true)

# %%
new_column_names = ["code",
"rollup_code",
"rollup_description"]
gender_df = gender_df.toDF(*new_column_names)

# %%
gender_df.printSchema()
# Out:
# root
#  |-- code: double (nullable = true)
#  |-- rollup_code: string (nullable = true)
#  |-- rollup_description: string (nullable = true)

# %%
group_df.printSchema()
# Out:
# root
#  |-- GROUP_ID: string (nullable = true)
#  |-- GROUP_NAME: string (nullable = true)

# %%
new_column_names = ["group_id", "group_name"]
group_df = group_df.toDF(*new_column_names)

# %%
group_df.printSchema()
# Out:
# root
#  |-- group_id: string (nullable = true)
#  |-- group_name: string (nullable = true)

# %%
coverage_df.printSchema()
# Out:
# root
#  |-- Coverage_ID: string (nullable = true)
#  |-- Coverage_Description: string (nullable = true)

# %%
new_column_names = ["coverage_id", "coverage_description"]
coverage_df = coverage_df.toDF(*new_column_names)

# %%
coverage_df.printSchema()
# Out:
# root
#  |-- coverage_id: string (nullable = true)
#  |-- coverage_description: string (nullable = true)

# %%
plan_df.printSchema()
# Out:
# root
#  |-- PLAN_ID: double (nullable = true)
#  |-- Plan Name: string (nullable = true)
#  |-- BENEFIT_TYPE: string (nullable = true)
#  |-- EFFECTIVE_DATE: timestamp (nullable = true)
#  |-- TERMINATION_DATE: timestamp (nullable = true)

# %%
new_column_names = ["plan_id",
"plan_name",
"benefit_type",
"effective_date",
"termination_date"
]
plan_df = plan_df.toDF(*new_column_names)

# %%
plan_df.printSchema()
# Out:
# root
#  |-- plan_id: double (nullable = true)
#  |-- plan name: string (nullable = true)
#  |-- benefit_type: string (nullable = true)
#  |-- effective_date: timestamp (nullable = true)
#  |-- termination_date: timestamp (nullable = true)

# %%
relationship_df.printSchema()
# Out:
# root
#  |-- Rollup_Code: string (nullable = true)
#  |-- Rollup_Description: string (nullable = true)

# %%
new_column_names = ["rollup_code", "rollup_description"]
relationship_df = relationship_df.toDF(*new_column_names)

# %%
relationship_df.printSchema()
# Out:
# root
#  |-- rollup_code: string (nullable = true)
#  |-- rollup_description: string (nullable = true)

# %%
print(enrollment_df.count())
# Out:
# 99

# %%
print(demographics_df.count())
# Out:
# 99

# %%
final_df = enrollment_df.join(
    demographics_df,
    enrollment_df.member_id == demographics_df.member_id,
    "left"
).drop(demographics_df["member_id"])

# %%
final_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
</td><td>Flynn</td><td>Morrison</td><td>null</td><td>0.0</td><td>1989-03-30</td><td>M</td><td>04</td><td>white</td><td>nonhispanic</td><td>164 Stokes Lodge Apt 34</td><td>null</td><td>Winchendon</td><td>Massachusetts</td><td>Worcester County</td><td>01475</td></tr><tr><td>150400</td><td>ACTIVE</td><td>1</td><td>E</td><td>0.0</td><td>Aetna</td><td>2020-12-01T00:00:00.000+0000</td><td>2021-01-31</td><td>151731</td><td>Jayden</td><td>Kane</td><td>null</td><td>0.0</td><td>2019-07-08</td><td>F</td><td>03</td><td>white</td><td>hispanic</td><td>1054 Price Glen</td><td>null</td><td>Haverhill</td><td>Massachusetts</td><td>Essex County</td><td>01835</td></tr><tr><td>114100</td><td>ACTIVE</td><td>8</td><td>F</td><td>10.0</td><td>Cigna</td><td>2019-12-01T00:00:00.000+0000</td><td>2020-01-31</td><td>152105</td><td>Safa</td><td>Kelly</td><td>null</td><td>0.0</td>< ...

# %%
final_df = final_df.join(
    gender_df,
    final_df.gender == gender_df.code,
    "left"
) \
.drop("code") \
.withColumnRenamed("rollup_description", "gender_description") \
.withColumnRenamed("gender", "gender_code") \
.withColumnRenamed("rollup_code", "gender")

final_df = final_df.join(
    group_df,
    final_df.group_id == group_df.group_id,
    "left"
) \
.drop(group_df["group_id"])

final_df = final_df.join(
    coverage_df,
    final_df.coverage_type == coverage_df.coverage_id,
    "left"
) \
.drop(coverage_df["coverage_id"])

final_df = final_df.join(
    plan_df,
    final_df.plan_id == plan_df.plan_id,
    "left"
) \
.select(final_df["*"], plan_df["plan_name"], plan_df["benefit_type"], plan_df["effective_date"].alias("plan_effective_date"), plan_df["termination_date"].alias("plan_termination_date"))

final_df.display()

# .join(
#     relationship_df,
#     final_df.relationship == relationship_df.rollup_code,
#     "left"
# ) \
# .drop("rollup_code") \
# .withColumnRenamed("rollup_description", "relationship_description") \
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>member_id</th><th>member_status</th><th>group_id</th><th>coverage_type</th><th>plan_id</th><th>vendor</th><th>effective_date</th><th>termination_date</th><th>employee_id</th><th>first_name</th><th>last_name</th><th>middle_name</th><th>gender_code</th><th>dob</th><th>relationship</th><th>person_code</th><th>race</th><th>ethnicity</th><th>address_1</th><th>address_2</th><th>city</th><th>state</th><th>county</th><th>zip</th><th>gender</th><th>gender_description</th><th>group_name</th><th>coverage_description</th><th>plan_name</th><th>benefit_type</th><th>plan_effective_date</th><th>plan_termination_date</th></tr></thead><tbody><tr><td>21800</td><td>ACTIVE</td><td>8</td><td>E1C</td><td>4.0</td><td>Aetna</td><td>2020-12-01T00:00:00.000+0000</td><td>2021-01-31</td><td>13587</td><td>Amelie</td><td>Harmon</td><td>null</td><td>0.0</td><td>1984-04-08</td><td>D2</td><td>16</td><td>other</td><td>nonhispanic</td><td>958 Robel Run Unit 83</td><td>null</td><td>Carver</td><td>Massachusetts</td><td>Plymouth County</td><td></td><td>F</td><td>Female</td><td>TechKraft Inc</td><td>Employee and 1 Child</td><td>Plan E</td><td>Medical</td><td>2019-01-01T00: