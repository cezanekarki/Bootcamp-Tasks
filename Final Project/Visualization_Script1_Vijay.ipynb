# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # read data from csv files

# %%
sales = pd.read_csv("/home/sunbeam/1_dct/Sales.csv")
sales
# Out:
#     transaction_id  customer_id  product_id transaction_date  amount_paid
# 0                1            3           3    01-05-23 0:00          613
# 1                2           19           9    03-07-23 0:00          227
# 2                3            9          10    25-10-23 0:00          891
# 3                4            4           3    28-05-23 0:00          342
# 4                5           15           6    18-04-23 0:00           91
# ..             ...          ...         ...              ...          ...
# 95              96           15           2    05-03-23 0:00          124
# 96              97            6           3    20-06-23 0:00          974
# 97              98            6           1    26-03-23 0:00          578
# 98              99            4           4    09-12-23 0:00          265
# 99             100           15           2    24-07-23 0:00          735
#
# [100 rows x 5 columns]

# %%
customers = pd.read_csv("/home/sunbeam/1_dct/Customers.csv")
customers
# Out:
#     customer_id         name                   email         phone
# 0             1   Customer 1   customer1@example.com  123-456-0001
# 1             2   Customer 2   customer2@example.com  123-456-0002
# 2             3   Customer 3   customer3@example.com  123-456-0003
# 3             4   Customer 4   customer4@example.com  123-456-0004
# 4             5   Customer 5   customer5@example.com  123-456-0005
# 5             6   Customer 6   customer6@example.com  123-456-0006
# 6             7   Customer 7   customer7@example.com  123-456-0007
# 7             8   Customer 8   customer8@example.com  123-456-0008
# 8             9   Customer 9   customer9@example.com  123-456-0009
# 9            10  Customer 10  customer10@example.com  123-456-0010
# 10           11  Customer 11  customer11@example.com  123-456-0011
# 11           12  Customer 12  customer12@example.com  123-456-0012
# 12           13  Customer 13  customer13@example.com  123-456-0013
# ...

# %%
products = pd.read_csv("//home/sunbeam/1_dct/Products.csv")
products
# Out:
#    product_id product_name    category  price  stock_quantity
# 0           1    Product 1  Category 1    232              37
# 1           2    Product 2  Category 1    185              74
# 2           3    Product 3  Category 3    171              72
# 3           4    Product 4  Category 3    154              43
# 4           5    Product 5  Category 2    207              96
# 5           6    Product 6  Category 3    496              37
# 6           7    Product 7  Category 1    166              23
# 7           8    Product 8  Category 1    205              81
# 8           9    Product 9  Category 3    303              13
# 9          10   Product 10  Category 1    447              95

# %%
employee = pd.read_csv("/home/sunbeam/1_dct/Employee.csv")
employee
# Out:
#    employee_id employee_name    role    department
# 0            1    Employee 1  Role 2  Department 3
# 1            2    Employee 2  Role 2  Department 1
# 2            3    Employee 3  Role 1  Department 2
# 3            4    Employee 4  Role 1  Department 2
# 4            5    Employee 5  Role 1  Department 3
# 5            6    Employee 6  Role 3  Department 1
# 6            7    Employee 7  Role 3  Department 1
# 7            8    Employee 8  Role 3  Department 2
# 8            9    Employee 9  Role 2  Department 2
# 9           10   Employee 10  Role 3  Department 2

# %%
employee_sales = pd.read_csv("/home/sunbeam/1_dct/EmployeeSale.csv")
employee_sales
# Out:
#     sale_id  employee_id  transaction_id      sale_date  amount
# 0         1           10              33  23-03-23 0:00     480
# 1         2            9              21  28-11-23 0:00     705
# 2         3            7               4  19-04-23 0:00     716
# 3         4            9              10  05-11-23 0:00     242
# 4         5            9              69  08-11-23 0:00      17
# ..      ...          ...             ...            ...     ...
# 95       96            8              46  09-03-23 0:00     664
# 96       97            4              36  28-06-23 0:00      10
# 97       98            5              30  20-07-23 0:00     949
# 98       99           10              20  19-04-23 0:00     355
# 99      100            7              82  14-12-23 0:00     287
#
# [100 rows x 5 columns]

# %%
sales
# Out:
#     transaction_id  customer_id  product_id transaction_date  amount_paid
# 0                1            3           3    01-05-23 0:00          613
# 1                2           19           9    03-07-23 0:00          227
# 2                3            9          10    25-10-23 0:00          891
# 3                4            4           3    28-05-23 0:00          342
# 4                5           15           6    18-04-23 0:00           91
# ..             ...          ...         ...              ...          ...
# 95              96           15           2    05-03-23 0:00          124
# 96              97            6           3    20-06-23 0:00          974
# 97              98            6           1    26-03-23 0:00          578
# 98              99            4           4    09-12-23 0:00          265
# 99             100           15           2    24-07-23 0:00          735
#
# [100 rows x 5 columns]

# %%
# Create the countplot to get number of transaction made by each customer
sns.countplot(data=sales, x='customer_id')
plt.title('Count of Transactions by Customer ')
plt.xlabel('Customer ID')
plt.ylabel('Count of Transactions')
plt.show()

# %%
# create a countplot to  get number of transaction made on each product
sns.countplot(data=sales, x='product_id')
plt.title('Count of Transactions on  Each Product ')
plt.xlabel('Product ID')
plt.ylabel('Count of Transactions')
plt.show()

# %%
# to just cross check
s = sales[sales['product_id'] == 1]
s
# Out:
#     transaction_id  customer_id  product_id transaction_date  amount_paid
# 6                7            6           1    16-12-23 0:00          654
# 14              15           15           1    07-02-23 0:00          612
# 38              39           14           1    07-08-23 0:00          250
# 46              47            3           1    06-12-23 0:00          676
# 59              60           10           1    21-11-23 0:00          292
# 74              75            2           1    10-03-23 0:00           25
# 83              84           18           1    17-07-23 0:00          484
# 86              87            1           1    07-04-23 0:00           25
# 93              94           18           1    08-02-23 0:00          305
# 97              98            6           1    26-03-23 0:00          578

# %%
#This code calculates the total amount paid by each customer and  visualizes it using a bar plot to 
# understand this easily

total_amount_paid = sales.groupby('customer_id')['amount_paid'].sum().reset_index()


sns.barplot(data=total_amount_paid, x='customer_id', y='amount_paid')
plt.title('Total Amount Paid by  Each Customer')
plt.xlabel('Customer ID')
plt.ylabel('Total Amount Paid')
plt.xticks(rotation=45)
plt.show()

# %%
total_amount_paid = sales.groupby('customer_id')['amount_paid'].sum()
total_amount_paid
# Out:
# customer_id
# 1     1328
# 2     1978
# 3     1985
# 4     4844
# 5     3190
# 6     4595
# 7     1087
# 8     1465
# 9     1325
# 10    2487
# 11    3214
# 12    1072
# 13    2950
# 14     641
# 15    2353
# 16    1179
# 17    2821
# 18    3677
# 19    3622
# 20    1138
# Name: amount_paid, dtype: int64

# %%
#This code calculates the total sales by each product and  visualizes it using a bar plot to 
# understand this easily
total_amount_paid = sales.groupby('product_id')['amount_paid'].sum().reset_index()

sns.barplot(data=total_amount_paid, x='product_id', y='amount_paid')
plt.title('Total  Sales Amount per product')
plt.xlabel('Product ID')
plt.ylabel('Total Amount Paid')
plt.xticks(rotation=45)
plt.show()

# %%
total_amount_paid = sales.groupby('product_id')['amount_paid'].sum()
total_amount_paid
# Out:
# product_id
# 1     3901
# 2     5522
# 3     4659
# 4     4218
# 5     5275
# 6     4779
# 7     5131
# 8     5368
# 9     2648
# 10    5450
# Name: amount_paid, dtype: int64

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   transaction_id     100 non-null    int64
#  1   customer_id        100 non-null    int64
#  2   product_id         100 non-null    int64
#  3   transaction_date   100 non-null    datetime64[ns]
#  4   amount_paid        100 non-null    int64
#  5   transaction_month  100 non-null    period[M]
# dtypes: datetime64[ns](1), int64(4), period[M](1)
# memory usage: 4.8 KB

# %%
sales
# Out:
#     transaction_id  customer_id  product_id transaction_date  amount_paid
# 0                1            3           3       2023-01-05          613  \
# 1                2           19           9       2023-03-07          227
# 2                3            9          10       2023-10-25          891
# 3                4            4           3       2023-05-28          342
# 4                5           15           6       2023-04-18           91
# ..             ...          ...         ...              ...          ...
# 95              96           15           2       2023-05-03          124
# 96              97            6           3       2023-06-20          974
# 97              98            6           1       2023-03-26          578
# 98              99            4           4       2023-09-12          265
# 99             100           15           2       2023-07-24          735
#
#    transaction_month  year  month
# 0            2023-01  2023      1
# ...

# %%
import pandas as pd

data = {
    'year': [2023]*12,
    'month': list(range(1, 13)),
    'total_sales_amount': [2038, 2319, 3203, 2953, 4876, 6602, 4238, 2009, 3283, 4622, 4440, 6368]
}

df = pd.DataFrame(data)
print(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   year                12 non-null     int64
#  1   month               12 non-null     int64
#  2   total_sales_amount  12 non-null     int64
# dtypes: int64(3)
# memory usage: 416.0 bytes

# %%
#visualize the monthly sales data from the DataFrame as a bar plot, where each bar represents the total sales 
#amount for a specific month
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='month', y='total_sales_amount', color='orange')

# Add total sales values on respective bars
for index, row in df.iterrows():
    plt.text(row.name, row['total_sales_amount'], str(row['total_sales_amount']), ha='center', va='bottom')

plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Total Sales Amount')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='month', y='total_sales_amount', color='orange')
plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Total Sales Amount')
plt.xticks(rotation=45)

# Adding annotations
for index, row in df.iterrows():
    plt.text(row['month'], row['total_sales_amount'], str(row['total_sales_amount']), ha='right')

plt.tight_layout()
plt.show()

# %%
customers
# Out:
#     customer_id         name                   email         phone
# 0             1   Customer 1   customer1@example.com  123-456-0001
# 1             2   Customer 2   customer2@example.com  123-456-0002
# 2             3   Customer 3   customer3@example.com  123-456-0003
# 3             4   Customer 4   customer4@example.com  123-456-0004
# 4             5   Customer 5   customer5@example.com  123-456-0005
# 5             6   Customer 6   customer6@example.com  123-456-0006
# 6             7   Customer 7   customer7@example.com  123-456-0007
# 7             8   Customer 8   customer8@example.com  123-456-0008
# 8             9   Customer 9   customer9@example.com  123-456-0009
# 9            10  Customer 10  customer10@example.com  123-456-0010
# 10           11  Customer 11  customer11@example.com  123-456-0011
# 11           12  Customer 12  customer12@example.com  123-456-0012
# 12           13  Customer 13  customer13@example.com  123-456-0013
# ...

# %%
sales_customers = pd.merge(sales, customers, on='customer_id', how='inner')

# %%
sales_customers
# Out:
#     transaction_id  customer_id  product_id transaction_date  amount_paid
# 0                1            3           3       2023-01-05          613  \
# 1               40            3           4       2023-03-14          696
# 2               47            3           1       2023-06-12          676
# 3                2           19           9       2023-03-07          227
# 4               10           19           5       2023-12-09          667
# ..             ...          ...         ...              ...          ...
# 95              61            2           2       2023-07-22          832
# 96              62            2           8       2023-09-28          373
# 97              66            2           4       2023-04-25          279
# 98              75            2           1       2023-10-03           25
# 99              92            2           3       2023-11-05          308
#
#    transaction_month  year  month         name                   email
# ...

# %%
employee_employeesales = pd.merge(employee, employee_sales, on='employee_id', how='inner')
employee_employeesales
employee_employeesales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   employee_id     100 non-null    int64
#  1   employee_name   100 non-null    object
#  2   role            100 non-null    object
#  3   department      100 non-null    object
#  4   sale_id         100 non-null    int64
#  5   transaction_id  100 non-null    int64
#  6   sale_date       100 non-null    object
#  7   amount          100 non-null    int64
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
employee
# Out:
#    employee_id employee_name    role    department
# 0            1    Employee 1  Role 2  Department 3
# 1            2    Employee 2  Role 2  Department 1
# 2            3    Employee 3  Role 1  Department 2
# 3            4    Employee 4  Role 1  Department 2
# 4            5    Employee 5  Role 1  Department 3
# 5            6    Employee 6  Role 3  Department 1
# 6            7    Employee 7  Role 3  Department 1
# 7            8    Employee 8  Role 3  Department 2
# 8            9    Employee 9  Role 2  Department 2
# 9           10   Employee 10  Role 3  Department 2

# %%
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   employee_id    10 non-null     int64
#  1   employee_name  10 non-null     object
#  2   role           10 non-null     object
#  3   department     10 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 448.0+ bytes

# %%
department_counts = employee['department'].value_counts()
department_counts
# Out:
# department
# Department 2    5
# Department 1    3
# Department 3    2
# Name: count, dtype: int64

# %%
#here we creates a pie chart  to visualize the distribution of employees across different departments,
#displaying the percentage of employees in each department.

department_counts = employee['department'].value_counts()
plt.figure(figsize=(8, 8))
sns.set_palette("pastel")
plt.pie(department_counts, labels=department_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Employee Distribution by Department')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
role_counts = employee['role'].value_counts()
role_counts
# Out:
# role
# Role 3    4
# Role 2    3
# Role 1    3
# Name: count, dtype: int64

# %%
#here we creates a pie chart  to visualize the distribution of employees across different roles,
#displaying the percentage of employees in each role.

role_counts = employee['role'].value_counts()
plt.figure(figsize=(8, 8))
sns.set_palette("pastel")
plt.pie(department_counts, labels=department_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Employee Distribution by Role')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
employee_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sale_id         100 non-null    int64
#  1   employee_id     100 non-null    int64
#  2   transaction_id  100 non-null    int64
#  3   sale_date       100 non-null    object
#  4   amount          100 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 4.0+ KB

# %%
total_sales_per_employee = employee_sales.groupby('employee_id')['amount'].sum().reset_index()
total_sales_per_employee
# Out:
#    employee_id  amount
# 0            1    5729
# 1            2    2992
# 2            3    2395
# 3            4    3024
# 4            5    5172
# 5            6    5853
# 6            7    4181
# 7            8    4064
# 8            9   10859
# 9           10    5327

# %%
#here we create bar plot to get total sales of each employee

plt.figure(figsize=(10, 6))
sns.barplot(data=total_sales_per_employee, x='employee_id', y='amount')
plt.title('Total Sales per Employee')
plt.xlabel('Employee ID')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)

# Adding total sales values on respective bars
for index, row in total_sales_per_employee.iterrows():
    plt.text(row.name, row['amount'] + 100, str(row['amount']), ha='center', color='black')

plt.tight_layout()
plt.show()

# %%
employee_sales
# Out:
#     sale_id  employee_id  transaction_id      sale_date  amount
# 0         1           10              33  23-03-23 0:00     480
# 1         2            9              21  28-11-23 0:00     705
# 2         3            7               4  19-04-23 0:00     716
# 3         4            9              10  05-11-23 0:00     242
# 4         5            9              69  08-11-23 0:00      17
# ..      ...          ...             ...            ...     ...
# 95       96            8              46  09-03-23 0:00     664
# 96       97            4              36  28-06-23 0:00      10
# 97       98            5              30  20-07-23 0:00     949
# 98       99           10              20  19-04-23 0:00     355
# 99      100            7              82  14-12-23 0:00     287
#
# [100 rows x 5 columns]

# %%
products
# Out:
#    product_id product_name    category  price  stock_quantity
# 0           1    Product 1  Category 1    232              37
# 1           2    Product 2  Category 1    185              74
# 2           3    Product 3  Category 3    171              72
# 3           4    Product 4  Category 3    154              43
# 4           5    Product 5  Category 2    207              96
# 5           6    Product 6  Category 3    496              37
# 6           7    Product 7  Category 1    166              23
# 7           8    Product 8  Category 1    205              81
# 8           9    Product 9  Category 3    303              13
# 9          10   Product 10  Category 1    447              95

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      10 non-null     int64
#  1   product_name    10 non-null     object
#  2   category        10 non-null     object
#  3   price           10 non-null     int64
#  4   stock_quantity  10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 528.0+ bytes

# %%
# count number of products in each category using countplot

plt.figure(figsize=(10, 6))
sns.countplot(data=products, x='category')
plt.title('Count of Products by Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
employee_employeesales
# Out:
#     employee_id employee_name    role    department  sale_id  transaction_id
# 0             1    Employee 1  Role 2  Department 3        9              86  \
# 1             1    Employee 1  Role 2  Department 3       16              14
# 2             1    Employee 1  Role 2  Department 3       28               5
# 3             1    Employee 1  Role 2  Department 3       29              48
# 4             1    Employee 1  Role 2  Department 3       30              99
# ..          ...           ...     ...           ...      ...             ...
# 95           10   Employee 10  Role 3  Department 2       48              39
# 96           10   Employee 10  Role 3  Department 2       49              68
# 97           10   Employee 10  Role 3  Department 2       71              81
# 98           10   Employee 10  Role 3  Department 2       79               9
# 99           10   Employee 10  Role 3  Department 2       99              20
#
#         sale_date  amount
# ...

# %%
# Group by employee_id and sum the amount column
total_sales_per_employee = employee_employeesales.groupby('employee_id')['amount'].sum().reset_index()

# Sort the data by total sales amount in descending order
total_sales_per_employee = total_sales_per_employee.sort_values(by='amount', ascending=False)

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(data=total_sales_per_employee, x='employee_id', y='amount', palette='viridis')
plt.title('Total Sales per Employee')
plt.xlabel('Employee ID')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
employee_sales
# Out:
#     sale_id  employee_id  transaction_id      sale_date  amount
# 0         1           10              33  23-03-23 0:00     480
# 1         2            9              21  28-11-23 0:00     705
# 2         3            7               4  19-04-23 0:00     716
# 3         4            9              10  05-11-23 0:00     242
# 4         5            9              69  08-11-23 0:00      17
# ..      ...          ...             ...            ...     ...
# 95       96            8              46  09-03-23 0:00     664
# 96       97            4              36  28-06-23 0:00      10
# 97       98            5              30  20-07-23 0:00     949
# 98       99           10              20  19-04-23 0:00     355
# 99      100            7              82  14-12-23 0:00     287
#
# [100 rows x 5 columns]

# %%
# Convert 'sale_date' column to datetime format
employee_sales['sale_date'] = pd.to_datetime(employee_sales['sale_date'])

# Extract month from 'sale_date' and create a new column 'sale_month'
employee_sales['sale_month'] = employee_sales['sale_date'].dt.month

# Group by sale_month and sum the amount column to get monthly sales
monthly_sales = employee_sales.groupby('sale_month')['amount'].sum().reset_index()


plt.figure(figsize=(10, 6))
sns.barplot(data=monthly_sales, x='sale_month', y='amount', palette='coolwarm')
plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)

# Adding sales values on respective bars
for index, row in monthly_sales.iterrows():
    plt.text(row.name, row['amount'], str(row['amount']), ha='center', va='bottom')

plt.tight_layout()
plt.show()
